# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install tensorflow
import tensorflow as tf
# Out:
# ...
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.7 kB ? eta -:--:--
#      -------------------------------------- 48.7/48.7 kB 610.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.2/390.3 MB 1.3 MB/s eta 0:04:58
#    ---------------------------------------- 0.2/390.3 MB 1.3 MB/s eta 0:04:58
#    ---------------------------------------- 0.2/390.3 MB 1.3 MB/s eta 0:04:58
#    ---------------------------------------- 0.2/390.3 MB 1.3 MB/s eta 0:04:58
#    ---------------------------------------- 0.2/390.3 MB 1.3 MB/s eta 0:04:58
# ...

# %%
data=pd.read_csv(r"C:\Users\admin\Downloads\Churn_Modelling (2).csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
data=data.drop(['RowNumber','Surname'], axis=1)

# %%
data.columns
# Out:
# Index(['CustomerId', 'CreditScore', 'Geography', 'Gender', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data.shape
# Out:
# (10000, 12)

# %%
data["Geography"].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
data["Gender"].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
data["Geography"]=label.fit_transform(data["Geography"])
data["Geography"].value_counts()
# Out:
# Geography
# 0    5014
# 1    2509
# 2    2477
# Name: count, dtype: int64

# %%
data["Gender"]=label.fit_transform(data["Gender"])
data["Gender"].value_counts()
# Out:
# Gender
# 1    5457
# 0    4543
# Name: count, dtype: int64

# %%
data.head(3)
# Out:
#    CustomerId  CreditScore  Geography  Gender  Age  Tenure    Balance  \
# 0    15634602          619          0       0   42       2       0.00
# 1    15647311          608          2       0   41       1   83807.86
# 2    15619304          502          0       0   42       8  159660.80
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1

# %%
data["Balance"] =data["Balance"].astype(int)
data.head(3)
# Out:
#    CustomerId  CreditScore  Geography  Gender  Age  Tenure  Balance  \
# 0    15634602          619          0       0   42       2        0
# 1    15647311          608          2       0   41       1    83807
# 2    15619304          502          0       0   42       8   159660
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1

# %%
x=data.drop(["Exited"],axis=1)
#x.head()

# %%
y=data["Exited"]
#y[:5]

# %%
#another method to do the same thing
x1=data.iloc[:,:-1] #iloc[rows,columns]
y1=data.iloc[:,-1]

# %%
df=sns.load_dataset("taxis")

# %%
from imblearn.over_sampling import SMOTE
s= SMOTE()
x_data, y_data=s.fit_resample(x, y)

# %%
from collections import Counter
print(Counter(y_data))
# Out:
# Counter({1: 7963, 0: 7963})

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
x_scaled=mms.fit_transform(x_data)
x_scaled
# Out:
# array([[0.27561613, 0.538     , 0.        , ..., 1.        , 1.        ,
#         0.50673489],
#        [0.32645436, 0.516     , 1.        , ..., 0.        , 1.        ,
#         0.56270874],
#        [0.21442143, 0.304     , 0.        , ..., 1.        , 0.        ,
#         0.56965435],
#        ...,
#        [0.27404406, 0.612     , 0.        , ..., 0.        , 0.        ,
#         0.03912742],
#        [0.40076163, 0.714     , 0.        , ..., 1.        , 0.        ,
#         0.31736765],
#        [0.53382749, 0.542     , 0.5       , ..., 0.        , 0.        ,
#         0.25876332]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x_scaled, y_data,test_size=0.25,random_state=300)

# %%
ann=tf.keras.models.Sequential()
ann
# Out:
# <Sequential name=sequential, built=False>

# %%
#Hidden layers
ann.add(tf.keras.layers.Dense(units=16,activation='relu'))
ann.add(tf.keras.layers.Dense(units=8,activation='relu'))
ann.add(tf.keras.layers.Dense(units=8,activation='relu'))
ann.add(tf.keras.layers.Dense(units=8,activation='relu'))
ann.add(tf.keras.layers.Dense(units=8,activation='relu'))

#Output Layers
ann.add(tf.keras.layers.Dense(units=1,activation='sigmoid'))

# %% [markdown]
# # Compiling and ANN model Training

# %%
ann.compile(optimizer='adam',loss='binary_crossentropy', metrics=["accuracy"])
ann.fit(x_train, y_train, batch_size=32,epochs=50)
# Out:
# Epoch 1/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.6520 - loss: 0.6090
# Epoch 2/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8269 - loss: 0.4002
# Epoch 3/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8253 - loss: 0.3939
# Epoch 4/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8304 - loss: 0.3898
# Epoch 5/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8252 - loss: 0.3924
# Epoch 6/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8301 - loss: 0.3875
# Epoch 7/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8250 - loss: 0.3898
# Epoch 8/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8251 - loss: 0.3843
# Epoch 9/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8244 - loss: 0.3918
# Epoch 10/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8324 - loss: 0.3804
# Epoch 11/50
# 374/374 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8383 - loss: 0.3710
# ...

# %%
def a(a,b):
    print(a + b)

# %%
a(22,67)
# Out:
# 89

# %%
def a(a=89,b=23):
    print(a + b)

# %%
a()
# Out:
# 112

# %%
def a(a=89,b=23):
    a=22
    b=11
    print(a + b)

# %%
a()
# Out:
# 33

# %%
def a(*a):
    print(a)

# %%
a(1,2,3,4,5)
# Out:
# (1, 2, 3, 4, 5)

# %%
# Install Required Libraries
# !pip install transformers

# Import Libraries
from transformers import pipeline
# Out:
# ...
#      ---------------------------------------- 0.0/43.5 kB ? eta -:--:--
#      ----------------- -------------------- 20.5/43.5 kB 320.0 kB/s eta 0:00:01
#      ----------------------------------- -- 41.0/43.5 kB 326.8 kB/s eta 0:00:01
#      -------------------------------------- 43.5/43.5 kB 302.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/10.1 MB 1.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/10.1 MB 1.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/10.1 MB 1.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/10.1 MB 1.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/10.1 MB 1.1 MB/s eta 0:00:10
#    ---------------------------------------- 0.1/10.1 MB 1.1 MB/s eta 0:00:10
# ...

# %%
# Load Summarization Pipeline
def load_summarizer():
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
    return summarizer
